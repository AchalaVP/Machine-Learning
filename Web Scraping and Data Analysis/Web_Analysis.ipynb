# %%
# !cd  /content/drive/MyDrive/20211030_Test_Assignment

# %%
# !pip install syllables
# Out:
# Collecting syllables
#   Downloading syllables-1.0.7-py3-none-any.whl (15 kB)
# Collecting cmudict<2.0.0,>=1.0.11 (from syllables)
#   Downloading cmudict-1.0.13-py3-none-any.whl (939 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 939.3/939.3 kB 7.9 MB/s eta 0:00:00
# Collecting importlib-metadata<6.0.0,>=5.1.0 (from syllables)
#   Downloading importlib_metadata-5.2.0-py3-none-any.whl (21 kB)
# Collecting importlib-resources<6.0.0,>=5.10.1 (from cmudict<2.0.0,>=1.0.11->syllables)
#   Downloading importlib_resources-5.13.0-py3-none-any.whl (32 kB)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata<6.0.0,>=5.1.0->syllables) (3.16.2)
# Installing collected packages: importlib-resources, importlib-metadata, cmudict, syllables
#   Attempting uninstall: importlib-resources
#     Found existing installation: importlib-resources 6.0.0
#     Uninstalling importlib-resources-6.0.0:
#       Successfully uninstalled importlib-resources-6.0.0
#   Attempting uninstall: importlib-metadata
#     Found existing installation: importlib-metadata 4.6.4
#     Uninstalling importlib-metadata-4.6.4:
#       Successfully uninstalled importlib-metadata-4.6.4
# Successfully installed cmudict-1.0.13 importlib-metadata-5.2.0 importlib-resources-5.13.0 syllables-1.0.7

# %%
import os
import requests
from bs4 import BeautifulSoup
import pandas as pd
import nltk
from textstat import text_standard
from nltk.tokenize import word_tokenize
from textblob import TextBlob
import syllables

# Download nltk data (only required once)
nltk.download('punkt')

def extract_article_text(url):
    try:
        response = requests.get(url)
        soup = BeautifulSoup(response.content, 'html.parser')
        article_title = soup.find('h1').text.strip()
        article_text = '\n'.join([p.text.strip() for p in soup.find_all('p')])
        return article_title, article_text
    except Exception as e:
        print(f"Error extracting article from URL: {url}")
        print(e)
        return None, None

def syllable_count(word):
    return syllables.estimate(word)

def compute_text_metrics(article_text):
    sentences = nltk.sent_tokenize(article_text)
    words = word_tokenize(article_text)

    num_syllables = sum([syllable_count(word) for word in words])
    num_complex_words = sum([1 for word in words if syllable_count(word) >= 3])

    avg_sentence_length = len(words) / len(sentences)
    avg_word_length = sum(len(word) for word in words) / len(words)

    personal_pronouns = sum(1 for word in words if word.lower() in ['i', 'me', 'my', 'mine', 'we', 'us', 'our', 'ours'])

    # Perform sentiment analysis using TextBlob
    blob = TextBlob(article_text)
    sentiment_score = blob.sentiment.polarity
    subjectivity_score = blob.sentiment.subjectivity

    return {
        'POSITIVE SCORE': sentiment_score if sentiment_score > 0 else 0,
        'NEGATIVE SCORE': abs(sentiment_score) if sentiment_score < 0 else 0,
        'POLARITY SCORE': sentiment_score,
        'SUBJECTIVITY SCORE': subjectivity_score,
        'AVG SENTENCE LENGTH': avg_sentence_length,
        'PERCENTAGE OF COMPLEX WORDS': (num_complex_words / len(words)) * 100,
        'FOG INDEX': text_standard(article_text, float_output=True),
        'AVG NUMBER OF WORDS PER SENTENCE': len(words) / len(sentences),
        'COMPLEX WORD COUNT': num_complex_words,
        'WORD COUNT': len(words),
        'SYLLABLE PER WORD': num_syllables / len(words),
        'PERSONAL PRONOUNS': personal_pronouns,
        'AVG WORD LENGTH': avg_word_length
    }

def process_articles(input_file, output_file):
    df = pd.read_excel(input_file)
    results = []
    for index, row in df.iterrows():
        url_id = row['URL_ID']
        url = row['URL']
        article_title, article_text = extract_article_text(url)
        if article_title and article_text:
            metrics = compute_text_metrics(article_text)
            result = {
                'URL_ID': url_id,
                'URL': url,
                **metrics
            }
            results.append(result)
            print(f"Article {url_id} processed successfully.")

    output_df = pd.DataFrame(results)
    output_df.to_excel(output_file, index=False)
    print(f"Output saved to {output_file}.")

if __name__ == "__main__":
    input_file = "/content/drive/MyDrive/20211030_Test_Assignment/Input.xlsx"
    output_file = output_file = "/content/drive/MyDrive/Copy_of_Output_Data_Structure.xlsx"

    process_articles(input_file, output_file)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# Article 123.0 processed successfully.
# Article 321.0 processed successfully.
# Article 2345.0 processed successfully.
# Article 4321.0 processed successfully.
# Article 432.0 processed successfully.
# Article 2893.8 processed successfully.
# Article 3355.6 processed successfully.
# Article 3817.4 processed successfully.
# Article 4279.2 processed successfully.
# Article 4741.0 processed successfully.
# Article 5202.8 processed successfully.
# Article 5664.6 processed successfully.
# Article 6126.4 processed successfully.
# Article 6588.2 processed successfully.
# Article 7050.0 processed successfully.
# Article 7511.8 processed successfully.
# Article 7973.6 processed successfully.
# Article 8435.4 processed successfully.
# Article 8897.2 processed successfully.
# Article 9359.0 processed successfully.
# Article 9820.8 processed successfully.
# Article 10282.6 processed successfully.
# Article 10744.4 processed successfully.
# Article 11206.2 processed successfully.
# Error extracting article from URL: https://insights.blackcoffer.com/how-neural-networks-can-be-applied-in-various-areas-in-the-future/
# 'NoneType' object has no attribute 'text'
# Article 12129.8 processed successfully.
# Article 12591.6 processed successfully.
# Article 13053.4 processed successfully.
# Article 13515.2 processed successfully.
# Article 13977.0 processed successfully.
# Article 14438.8 processed successfully.
# Article 14900.6 processed successfully.
# Article 15362.4 processed successfully.
# Article 15824.2 processed successfully.
# Article 16286.0 processed successfully.
# Article 16747.8 processed successfully.
# Article 17209.6 processed successfully.
# Error extracting article from URL: https://insights.blackcoffer.com/covid-19-environmental-impact-for-the-future/
# 'NoneType' object has no attribute 'text'
# Article 18133.2 processed successfully.
# Article 18595.0 processed successfully.
# Article 19056.8 processed successfully.
# Article 19518.6 processed successfully.
# Article 19980.4 processed successfully.
# Article 20442.2 processed successfully.
# Article 20904.0 processed successfully.
# Article 21365.8 processed successfully.
# Article 21827.6 processed successfully.
# Article 22289.4 processed successfully.
# Article 22751.2 processed successfully.
# Article 23213.0 processed successfully.
# Article 23674.8 processed successfully.
# Article 24136.6 processed successfully.
# Article 24598.4 processed successfully.
# Article 25060.2 processed successfully.
# Article 25522.0 processed successfully.
# Article 25983.8 processed successfully.
# Article 26445.6 processed successfully.
# Article 26907.4 processed successfully.
# Article 27369.2 processed successfully.
# Article 27831.0 processed successfully.
# Article 28292.8 processed successfully.
# Article 28754.6 processed successfully.
# Article 29216.4 processed successfully.
# Article 29678.2 processed successfully.
# Article 30140.0 processed successfully.
# Article 30601.8 processed successfully.
# Article 31063.6 processed successfully.
# Article 31525.4 processed successfully.
# Article 31987.2 processed successfully.
# Article 32449.0 processed successfully.
# Article 32910.8 processed successfully.
# Article 33372.6 processed successfully.
# Article 33834.4 processed successfully.
# Article 34296.2 processed successfully.
# Article 34758.0 processed successfully.
# Article 35219.8 processed successfully.
# Article 35681.6 processed successfully.
# Article 36143.4 processed successfully.
# Article 36605.2 processed successfully.
# Article 37067.0 processed successfully.
# Article 37528.8 processed successfully.
# Article 37990.6 processed successfully.
# Article 38452.4 processed successfully.
# Article 38914.2 processed successfully.
# Article 39376.0 processed successfully.
# Article 39837.8 processed successfully.
# Article 40299.6 processed successfully.
# Article 40761.4 processed successfully.
# Article 41223.2 processed successfully.
# Article 41685.0 processed successfully.
# Article 42146.8 processed successfully.
# Article 42608.6 processed successfully.
# Article 43070.4 processed successfully.
# Article 43532.2 processed successfully.
# Article 43994.0 processed successfully.
# Article 44455.8 processed successfully.
# Article 44917.6 processed successfully.
# Article 45379.4 processed successfully.
# Article 45841.2 processed successfully.
# Article 46303.0 processed successfully.
# Article 46764.8 processed successfully.
# Article 47226.6 processed successfully.
# Article 47688.4 processed successfully.
# Article 48150.2 processed successfully.
# Article 48612.0 processed successfully.
# Article 49073.8 processed successfully.
# Article 49535.6 processed successfully.
# Article 49997.4 processed successfully.
# Article 50459.2 processed successfully.
# Article 50921.0 processed successfully.
# Article 51382.8 processed successfully.
# Article 51844.6 processed successfully.
# Article 52306.4 processed successfully.
# Article 52768.2 processed successfully.
# Output saved to /content/drive/MyDrive/Copy_of_Output_Data_Structure.xlsx.
